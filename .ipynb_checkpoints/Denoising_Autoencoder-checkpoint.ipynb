# %% [markdown]
# <a href="https://colab.research.google.com/github/JordanFoss/STAT3007_Project/blob/main/Denoising_Autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/JordanFoss/STAT3007_Project.git
# %cd STAT3007_Project/
# Out:
# Cloning into 'STAT3007_Project'...
# remote: Enumerating objects: 1916, done.
# remote: Counting objects: 100% (310/310), done.
# remote: Compressing objects: 100% (217/217), done.
# remote: Total 1916 (delta 152), reused 219 (delta 93), pack-reused 1606
# Receiving objects: 100% (1916/1916), 236.04 MiB | 4.56 MiB/s, done.
# Resolving deltas: 100% (495/495), done.
# Updating files: 100% (1511/1511), done.
# /home/jordan/Documents/UniversityStuff/2021/Stat3007/STAT3007_Project/STAT3007_Project

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import MNIST
import scipy
import numpy as np
import librosa

import glob

# %%
class Encoder(nn.Module):
  def __init__(self, filters):
    super(Encoder, self).__init__()
    (W, K, S) = (28, 5, 1)
    P = (W*S-W-S+K)//2
    self.conv = nn.Conv2d(1, filters, K, S, P)
  def forward(self, x):
    x = self.conv(x)
    x = nn.functional.relu(x)
    return x


class Decoder(nn.Module):
  def __init__(self, filters):
    super(Decoder,self).__init__()
    (W, K, S) = (28, 1, 1)
    P = (W*S-W-S+K)//2
    self.conv = nn.Conv2d(filters, 1, K, S, P)
  def forward(self, x):
    x = self.conv(x)
    x = nn.functional.relu(x)
    return x

class Autoencoder(nn.Module):
  def __init__(self, filters):
    super(Autoencoder,self).__init__()
    self.filters = filters
    self.encoder = Encoder(filters)
    self.decoder = Decoder(filters)
  def forward(self, x):
    x = self.encoder(x)
    x = self.decoder(x)
    return x

def noisify(img):
  noise = 0.4*torch.randn(img.shape).to(device)
  img = img + noise
  img = torch.clamp(img, 0, 1)
  return img

def train_AE(ae, dloader, nepochs, lr, clean_image):
  criterion = nn.MSELoss()
  optimizer = torch.optim.Adam(ae.parameters(), lr=lr)
  for epoch in range(nepochs):
    for (i, img) in enumerate(dloader):
      img = img.reshape(1,1,129,771).to(device)
      optimizer.zero_grad()
      out = ae(-img)
      loss = criterion(out, -clean_image.reshape(1,1,129,771))
      loss.backward()
      optimizer.step()
      print('[%2d,%3d] loss: %.6f' % (epoch+1,i+1,loss.item()),end='\r')
    print('\n', end ='\r')

# %%
def spectral_decomposition(sample,sampling_rate, eps = 1e-14, title = ' title placeholder', visualise = True):
    frequencies, times, spectrogram = scipy.signal.spectrogram(sample,fs = sampling_rate)

    
    
    
    if visualise:
      specgram = plt.pcolormesh(times, frequencies, np.log(spectrogram + eps),shading = 'auto')
      plt.clim(-40, -5)
      
      plt.colorbar(specgram)
      #plt.imshow(np.log(spectrogram))
      plt.ylabel('Frequency [Hz]')
      plt.xlabel('Time [sec]')
      plt.title(title)
      plt.show()
    
    return frequencies, times, np.log(spectrogram+ eps)

# %%
noisy_spectrograms = []
for name in glob.glob('/content/STAT3007_Project/sample-noisy-speech-actor-02/*'):

  noisy_samples, noisy_sampling_rate = librosa.load(name, sr = None)
  frequencies, times, spectrogram = spectral_decomposition(noisy_samples,noisy_sampling_rate, title = name, visualise = False)
  print(spectrogram.shape)
  noisy_spectrograms.append(spectrogram[:,:771])

clean_samples, clean_sampling_rate = librosa.load('./Audio_Speech_Actors_01-24/Female/Actor_02/01-01-01-01-02.wav', sr = None)
frequencies, times, spectrogram = spectral_decomposition(clean_samples,clean_sampling_rate, title = 'clean', visualise = False)
clean_spectrogram = spectrogram
# Out:
# (129, 779)
# (129, 779)
# (129, 807)
# (129, 772)
# (129, 779)
# (129, 779)
# (129, 779)
# (129, 779)
# (129, 779)
# (129, 779)

# %%
noisy_spectrograms[0].shape
# Out:
# (129, 771)

# %%
train_set = torch.tensor(noisy_spectrograms)
clean_spec = torch.tensor(clean_spectrogram[:,:771])

# %%
clean_spec.shape
# Out:
# torch.Size([129, 771])

# %%
# set device to GPU if available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# load MNIST training and testing data


dataloader_tn = DataLoader(train_set, shuffle=True,num_workers = 1)
#dataloader_ts = DataLoader(mnist_ts, batch_size=10000)
# train an autoencoder with 4 filters
ae = Autoencoder(4).to(device)
train_AE(ae, dataloader_tn, 10, 0.01, clean_spec)
torch.save(ae,'netAE')
# Out:
# [ 1, 10] loss: 15.194496
#
# [ 3, 10] loss: 27.167370
# [ 4, 10] loss: 12.496897
# [ 5, 10] loss: 12.701820
#
# [ 7, 10] loss: 14.530324
# [ 8, 10] loss: 14.766735
# [ 9, 10] loss: 11.672418
# [10, 10] loss: 8.759151

# %%
plt.pcolormesh(times[:771], frequencies, -ae(-train_set[0].reshape(1,1,129,771)).detach().numpy().reshape(129,771))

# %%
plt.pcolormesh(times[:771], frequencies,clean_spec)
